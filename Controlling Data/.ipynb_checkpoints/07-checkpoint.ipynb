# %% [markdown]
# # Chap7. 시계열 데이터를 다뤄보자

# %% [markdown]
# 7-1. Numpy의 polyfit으로 회귀 분석하기

# %%
# !pip install pystan
# !pip install prophet
# Out:
# ...
#   Created wheel for prophet: filename=prophet-0.1.1-cp37-none-any.whl size=12172 sha256=b2106b462f1fb6e4d58189fbbc4fd99fe15175905b0c9c47800ddce7d4d140c7
#   Stored in directory: C:\Users\eunju\AppData\Local\pip\Cache\wheels\77\3e\f3\1c536bf1f871f818686e7fbf31cab18d52787a72dea8640756
# Successfully built prophet
# ...

# %%
# !pip install datetime
# !pip install pandas_datareader

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from datetime import datetime

# %%
from fbprophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
path = "c:/Windows/Fonts/malgun.ttf"
import platform
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')    

plt.rcParams['axes.unicode_minus'] = False

# %%
pinkwink_web = pd.read_csv("C:\\Users\\eunju\\Desktop\\GitHub\\stat_python_practice\\Controlling Data\\Data\\08. PinkWink Web Traffic.csv",
                          encoding='utf-8', thousands=',',
                          names=['date','hit'], index_col=0)
pinkwink_web = pinkwink_web[pinkwink_web['hit'].notnull()]
pinkwink_web.head()
# Out:
#              hit
# date
# 16. 7. 1.  766.0
# 16. 7. 2.  377.0
# 16. 7. 3.  427.0
# 16. 7. 4.  902.0
# 16. 7. 5.  850.0

# %%
pinkwink_web['hit'].plot(figsize=(12,4), grid=True);

# %%
time = np.arange(0, len(pinkwink_web))
traffic = pinkwink_web['hit'].values

fx = np.linspace(0, time[-1], 1000)

# %%
#모델의 적합성을 확인하는 함수 생성
def error(f, x, y):
    return np.sqrt(np.mean((f(x)-y)**2))

# %%
#모델 생성(회귀)
fp1 = np.polyfit(time, traffic, 1)
f1 = np.poly1d(fp1)

fp2 = np.polyfit(time, traffic, 2)
f2 = np.poly1d(fp2)

fp3 = np.polyfit(time, traffic, 3)
f3 = np.poly1d(fp3)

fp15 = np.polyfit(time, traffic, 15)
f15 = np.poly1d(fp15)

print(error(f1, time, traffic))
print(error(f2, time, traffic))
print(error(f3, time, traffic))
print(error(f15, time, traffic))
# Out:
# 430.85973081109626
# 430.62841018946943
# 429.5328046676293
# 330.4777304274343

# %%
#그래프를 통해 회귀선 확인
plt.figure(figsize=(10,6))
plt.scatter(time,traffic,s=10)

plt.plot(fx,f1(fx),lw=4,label='f1')
plt.plot(fx,f2(fx),lw=4,label='f2')
plt.plot(fx,f3(fx),lw=4,label='f3')
plt.plot(fx,f15(fx),lw=4,label='f15')

plt.grid(True, linestyle='-', color='0.75')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# 7-2. Prophet 모듈을 이용한 forecast 예측

# %%
df = pd.DataFrame({'ds':pinkwink_web.index, 'y':pinkwink_web['hit']})
df.reset_index(inplace=True)
df['ds'] = pd.to_datetime(df['ds'], format="%y. %m. %d.")
del df['date']

m = Prophet(yearly_seasonality=True) #주기성이 연단위임
m.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=60)
future.tail()
# Out:
#             ds
# 420 2017-08-25
# 421 2017-08-26
# 422 2017-08-27
# 423 2017-08-28
# 424 2017-08-29

# %%
forecast = m.predict(future)
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail()
# Out:
#             ds         yhat   yhat_lower   yhat_upper
# 420 2017-08-25   912.761130   703.085570  1124.796857
# 421 2017-08-26   497.711704   272.714372   704.752745
# 422 2017-08-27   630.268176   430.304249   829.333648
# 423 2017-08-28  1182.888299   973.424287  1393.533403
# 424 2017-08-29  1218.800002  1011.386064  1414.635293

# %%
m.plot(forecast);

# %%
m.plot_components(forecast);

# %% [markdown]
# 7-3. Seasonal 시계열 분석으로 주식 데이터 분석하기

# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22414 sha256=b892286319e812768584504950a4606990daa3e66f0fb0cf0ad879bb0a768351
#   Stored in directory: C:\Users\eunju\AppData\Local\Temp\pip-ephem-wheel-cache-t_jk53la\wheels\f9\e3\5b\ec24dd2984b12d61e0abf26289746c2436a0e7844f26f2515c
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.9-cp37-none-any.whl size=8373 sha256=0cb2047e46941f55e9beb7d6095b56748dac62eb3ceefede33dcf74516b942d6
#   Stored in directory: C:\Users\eunju\AppData\Local\Temp\pip-ephem-wheel-cache-t_jk53la\wheels\37\fa\73\d492849e319038eb4d986f5152e4b19ffb1bc0639da84d2677
# Successfully built yfinance multitasking
# ...

# %%
from pandas_datareader import data
import yfinance as yf
yf.pdr_override()

start_date = '1990-1-1' 
end_date = '2017-6-30' 
KIA = data.get_data_yahoo('000270.KS', start_date, end_date)
    
# KIA = web.DataReader('KRX:000270','google',start,end) # 구글용... 동작이 안됨
# KIA = web.DataReader('000270.KS','yahoo',start,end) # 구글용... 동작이 안됨
KIA.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close  Adj Close   Volume
# Date
# 2012-06-18  79400.0  80500.0  79300.0  80000.0    80000.0  1758207
# 2012-06-19  80000.0  80400.0  79500.0  80000.0    80000.0  1075002
# 2012-06-20  80900.0  81000.0  79600.0  80000.0    80000.0   885863
# 2012-06-21  79700.0  80300.0  78700.0  78800.0    78800.0   787586
# 2012-06-22  77900.0  78200.0  77200.0  77500.0    77500.0  1091383

# %%
KIA['Close'].plot(figsize=(12,6), grid=True);

# %%
KIA_trunc = KIA[:'2016-12-31']
KIA_trunc
# Out:
#                Open     High      Low    Close  Adj Close   Volume
# Date
# 2012-06-18  79400.0  80500.0  79300.0  80000.0    80000.0  1758207
# 2012-06-19  80000.0  80400.0  79500.0  80000.0    80000.0  1075002
# 2012-06-20  80900.0  81000.0  79600.0  80000.0    80000.0   885863
# 2012-06-21  79700.0  80300.0  78700.0  78800.0    78800.0   787586
# 2012-06-22  77900.0  78200.0  77200.0  77500.0    77500.0  1091383
# ...             ...      ...      ...      ...        ...      ...
# 2016-12-23  38700.0  39350.0  38650.0  39100.0    39100.0  1070783
# 2016-12-26  39100.0  39350.0  38850.0  39000.0    39000.0   465612
# 2016-12-27  39050.0  39700.0  39050.0  39500.0    39500.0   879686
# 2016-12-28  38600.0  39100.0  38600.0  38950.0    38950.0   662314
# 2016-12-29  38700.0  39400.0  38700.0  39250.0    39250.0   586340
#
# [1122 rows x 6 columns]

# %%
df = pd.DataFrame({'ds':KIA_trunc.index,'y':KIA_trunc['Close']})
df.reset_index(inplace=True)
del df['Date']
df.head()
# Out:
#           ds        y
# 0 2012-06-18  80000.0
# 1 2012-06-19  80000.0
# 2 2012-06-20  80000.0
# 3 2012-06-21  78800.0
# 4 2012-06-22  77500.0

# %%
m = Prophet()
m.fit(df);
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 1482 2017-12-25
# 1483 2017-12-26
# 1484 2017-12-27
# 1485 2017-12-28
# 1486 2017-12-29

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds          yhat   yhat_lower    yhat_upper
# 1482 2017-12-25  18814.421502  -136.540602  37421.545888
# 1483 2017-12-26  18810.028320  -796.576911  37979.098094
# 1484 2017-12-27  18622.011185 -1093.782862  37562.727667
# 1485 2017-12-28  18419.557301 -1234.320897  37414.297907
# 1486 2017-12-29  18197.508694 -1110.929009  36905.419145

# %%
m.plot(forecast);

# %%
m.plot_components(forecast);

# %%
start_date = '2014-1-1' 
end_date = '2017-7-31' 
KIA = data.get_data_yahoo('000270.KS', start_date, end_date)
KIA['Close'].plot(figsize=(12,6), grid=True);
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
KIA_trunc = KIA[:'2017-05-31']
KIA_trunc['Close'].plot(figsize=(12,6), grid=True)

# %%
df = pd.DataFrame({'ds':KIA_trunc.index, 'y':KIA_trunc['Close']})
df.reset_index(inplace=True)
del df['Date']

# %%
m = Prophet()
m.fit(df);
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=61)
future.tail()
# Out:
#             ds
# 897 2017-07-27
# 898 2017-07-28
# 899 2017-07-29
# 900 2017-07-30
# 901 2017-07-31

# %%
forecast = m.predict(future)
m.plot(forecast);

# %%
plt.figure(figsize=(12,6))
plt.plot(KIA.index,KIA['Close'],label='real')
plt.plot(forecast['ds'],forecast['yhat'],label='forecast')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# 7-4. Grow Model과 Holiday Forecast

# %%
df = pd.read_csv('C:\\Users\\eunju\\Desktop\\GitHub\\stat_python_practice\\Controlling Data\\Data\\08. example_wp_R.csv')
df.head()
# Out:
#            ds    y
# 0  2008-01-30  394
# 1  2008-01-16  424
# 2  2008-01-17  408
# 3  2008-01-14  385
# 4  2008-01-15  369

# %%
df['y'] = np.log(df['y'])
df['cap'] = 8.5

# %%
m = Prophet(growth='logistic')
m.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=1826)
future['cap'] = 8.5
fsct = m.predict(future)
m.plot(fsct);

# %%
m.plot_components(fsct);
