# %% [markdown]
# # Chap10. 빅데이터 분석을 위한 Plot 기능

# %% [markdown]
# 10.1 Matplot의 기초

# %%
###직선그래프
import matplotlib.pyplot as plt
y= [1,2,3,4,5]
plt.plot(y)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
y= [1,2,3,4,5]
plt.plot(y)
plt.show()

# %%
import matplotlib.pyplot as plt
y= [13,16,15,18,16,17,16]
plt.plot(y)

# %%
plt.plot(range(len(y)),y);

# %%
x= ['Mon','Tue','Wed','Thur','Fri','Sat','Sun']
y1= [13,16,15,18,16,17,16]
y2= [17,14,17,16,15,15,14]
plt.plot(x,y1, label='Sold');
plt.plot(x,y2, label='On Shelves');
plt.xlabel('Daily')
plt.ylabel('No. of Books Sold')
plt.legend(loc="upper left")
plt.title('Le Petit Prince: Sold & Left')
# Out:
# Text(0.5,1,'Le Petit Prince: Sold & Left')

# %%
###점선그래프
x= [1,2,3,4,5]
y= [1,4,9,16,25]
plt.plot(x,y,'bo')
plt.axis([0,6,0,30])
plt.show()

# %% [markdown]
# 10.2 Numpy를 이용한 plot기능

# %%
import numpy as np
points= np.array([[1,1],[1,2],[1,3],[2,1],[2,2],[2,3],[3,1],[3,2],[3,3]])
p= np.array([2.5,2])

import matplotlib.pyplot as plt
plt.plot(points[:,0], points[:,1], "ro")
plt.plot(p[0], p[1], "bo")

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.linspace(0,5,10)
y= x**2
plt.plot(x,y)

# %%
x= np.linspace(0,10,20)
y1= x**2
y2= x**1.5
plt.plot(x,y1,"bo-", linewidth=2, markersize=12, label="First")
plt.plot(x,y2,"gs-", linewidth=2, markersize=12, label="Second")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis([-0.5,10.5,-5,105])
plt.legend(loc="upper left")
plt.savefig("mplot.pdf")

# %%
x= np.logspace(-1,1,20)
y1= x**2
y2= x**1.5
plt.plot(x,y1,"bo-", linewidth=2, markersize=12, label="First")
plt.plot(x,y2,"gs-", linewidth=2, markersize=12, label="Second")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis([-0.5,10.5,-5,105])
plt.legend(loc="upper left")
plt.savefig("mplot.pdf")

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.random.standard_normal(size=10000)
plt.hist(x)
# Out:
# (array([   8.,   94.,  534., 1623., 2746., 2855., 1539.,  508.,   81.,
#           12.]),
#  array([-3.87780163, -3.09764859, -2.31749556, -1.53734252, -0.75718948,
#          0.02296355,  0.80311659,  1.58326962,  2.36342266,  3.1435757 ,
#          3.92372873]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x, density=True)
# Out:
# (array([0.00102544, 0.01204892, 0.06844811, 0.20803611, 0.35198222,
#         0.36595384, 0.19726899, 0.06511543, 0.01038258, 0.00153816]),
#  array([-3.87780163, -3.09764859, -2.31749556, -1.53734252, -0.75718948,
#          0.02296355,  0.80311659,  1.58326962,  2.36342266,  3.1435757 ,
#          3.92372873]),
#  <a list of 10 Patch objects>)

# %%
y= np.random.randn(1000)
plt.hist(y)
# Out:
# (array([  2.,   9.,  48., 158., 275., 263., 171.,  51.,  17.,   6.]),
#  array([-3.63684934, -2.92267801, -2.20850669, -1.49433536, -0.78016403,
#         -0.0659927 ,  0.64817863,  1.36234996,  2.07652129,  2.79069261,
#          3.50486394]),
#  <a list of 10 Patch objects>)

# %%
x= np.random.rand(30)
y= np.random.rand(30)
colors= np.random.rand(30)
shape= np.pi*(np.random.rand(30)*20)**2
plt.scatter(x,y,s=shape,c=colors,marker='*',alpha=0.7)
plt.show()
